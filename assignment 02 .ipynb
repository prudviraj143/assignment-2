# %%
#eligible for voting
age=int(input("Enter your age:"))
print("you are eligible for voting"if age>18 else "you are not eligible for voting")
# Out:
# Enter your age:21
# you are eligible for voting

# %%
#even or odd
num=int(input("enter a number:"))
if(num%2)==0:
  print("{0} is even ".format(num))
else:  
  print("{0} is odd".format(num))
# Out:
# enter a number:34
# 34 is even

# %%
#prime or not
#prime's are greater than 1
if num>1:
  for i in range(2,num):
    if (num%i)==0:
      print(num,"is not a prime number")
      print(i,"times",num//i,"is",num)
      break
    else:
      print(num,"is a prime number")
  else:
      print(num,"is not aprime")
# Out:
# 34 is not a prime number
# 2 times 17 is 34

# %%
#positive or not
num=float(input("enter the number:"))
if num > 0:
  print("positive number")
elif num==0:
  print("zero")
else:
  print("negative number")
# Out:
# enter the number:0
# zero

# %%
#quadratic equation
import math 
a = int(input("Please Enter a Value of a Quadratic Equation : "))
b = int(input("Please Enter b Value of a Quadratic Equation : "))
c = int(input("Please Enter c Value of a Quadratic Equation : "))

discriminant = (b * b) - (4 * a * c)

if(discriminant > 0):
    root1 = (-b + math.sqrt(discriminant) / (2 * a))
    root2 = (-b - math.sqrt(discriminant) / (2 * a))
    print("Two Distinct Real Roots Exists: root1 = %.2f and root2 = %.2f" %(root1, root2))
elif(discriminant == 0):
    root1 = root2 = -b / (2 * a)
    print("Two Equal and Real Roots Exists: root1 = %.2f and root2 = %.2f" %(root1, root2))
elif(discriminant < 0):
    root1 = root2 = -b / (2 * a)
    imaginary = math.sqrt(-discriminant) / (2 * a)
    print("Two Distinct Complex Roots Exists: root1 = %.2f+%.2f and root2 = %.2f-%.2f" %(root1, imaginary, root2, imaginary))
# Out:
# Please Enter a Value of a Quadratic Equation : 25
# Please Enter b Value of a Quadratic Equation : 30
# Please Enter c Value of a Quadratic Equation : 45
# Two Distinct Complex Roots Exists: root1 = -0.60+1.20 and root2 = -0.60-1.20

# %%
#using nested if check whether a number is + or - or 0
num=int(input("enter number:"))
if num < 0:
  print("entered number is negative.")
elif num > 0:  
  print("entered number is positive.")
elif num==0:
  print("entered number is zero.")  
else:
  print("the input is not a number")
# Out:
# enter number:45
# entered number is positive.

# %%
#accept a number to print in words
ch = input("Enter a character: ")

if(ch=='A' or ch=='a' or ch=='E' or ch =='e' or ch=='I'
 or ch=='i' or ch=='O' or ch=='o' or ch=='U' or ch=='u'):
    print(ch, "is a Vowel")
else:
    print(ch, "is a Consonant")
# Out:
# Enter a character: d
# d is a Consonant

# %%
#word number
num=int(input("enter the number between 1-5="))
if(num<=5 and num >0):
  if num==1:
    print("one")
  elif num==2:
    print("two")
  elif num==3:
    print("three")    
  elif num==4:
    print("four")  
  elif num==5:
    print("five")  
else:
  print("entered number is not in between 1-5")
# Out:
# enter the number between 1-5=4
# four
